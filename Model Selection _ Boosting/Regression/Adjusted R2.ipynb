# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravpks/ml-repo/blob/master/Model%20Selection%20_%20Boosting/Regression/Adjusted%20R2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Adjusted R2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No formula for Adjusted R2??? Why??

# %%
from sklearn import metrics

# %%
Adj R2 = 1 - (1-metrics.r2_score(y_test, y_pred))*(len(y)-1)/(len(y)-X.shape[1]-1)
